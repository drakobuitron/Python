# %% [markdown]
# **Normalizing data with standart deviation**
# JUAREZ RAMIREZ LUIS ENRIQUE ESCOM IPN 4AV1

# %%
import pandas as pd
from matplotlib import pyplot as plt
import math

vector=pd.read_csv("Muestra1G.csv")
vector=vector.iloc[20:3755,0:2]
vector2=pd.read_csv("MUESTRA2G.csv")
vector2=vector2.iloc[20:3755,0:2]

lista1=vector.iloc[0:,1:2].values.tolist()
lista2=vector2.iloc[0:,1:2].values.tolist()
CX=vector.iloc[:,0:1].values.tolist()

# %%
lista1A=[]
lista2A=[]
listaX=[]
for i in range(len(lista1)):
  lista1A.append(float(lista1[i][0]))
  lista2A.append(float(lista2[i][0]))
  listaX.append(float(CX[i][0]))
plt.plot(lista1A,color="blue")
plt.plot(lista2A,color="red")

# %%
prom2=sum(lista2A)/len(lista2A)
listaNormalizada1=[]
listaNormalizada2=[]
Prom=sum(lista1A)/len(lista1A)

#fiding standart deviation
for i in range(len(lista1A)):
    a=lista1A[i]-prom
    b=pow(a,2)
    c=b/len(lista1A)
    listaNormalizada1.append(c)

# %%
for i in range(len(lista2A)):
    a1=lista2A[i]-prom2
    b1=pow(a,2)
    c1=b1/len(lista2A)
    listaNormalizada2.append(c1)

# %%
plt.plot(listaNormalizada1,color="blue")
plt.plot(listaNormalizada2,color="red")
